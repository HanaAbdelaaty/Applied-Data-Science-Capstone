# %% [markdown]
# # **A program For Photographers Event**

# %% [markdown]
# ## **Introduction**

# %% [markdown]
# ABC is a company based in Toronto for organizing events, currently it works on a project to organize an event for 5 days for a group of photographers from all over the world.The company has to put a good program, including a hotel of residence, a hall for meetings,
# places of landscape to visit, stores for shopping, restaurants and cafes. So the company’s purpose is to make a list of places of landscape in Toronto, including the nearest restaurants, cafes, and shopping stores for each place.

# %% [markdown]
# ## **Data Description**

# %% [markdown]
# The data used in this project is provided by Foursquare location data. The data are grouped by landscape area, and each area included the information about this area and all information about restaurants, cafes, and stores which in this area.

# %% [markdown]
# ## **Table of contents**

# %% [markdown]
# #### 01- Import Libraries
# #### 02- Define Foursquare Credentials
# #### 03- Define the city and get its latitude & longitude
# #### 04- Search for Hotels & clean dataframe
# #### 05- Search for Parks & clean dataframe
# #### 06- Search for Restaurants & clean dataframe
# #### 07- Search for Cafeteria & clean dataframe
# #### 08- Search for Shopping Stores & clean dataframe
# #### 09- Generate map to visualize hotels, shopping stores and Cafeteria and how they cluster together
# #### 10- Generate map to visualize Park, Restaurant and Cafeteria and how they cluster together

# %% [markdown]
# ## **Import Libraries**

# %%
import requests # to handle requests
import pandas as pd # for data analsysis
import numpy as np # to handle data in a vectorized manner

# !conda install -c conda-forge geopy --yes 
from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values

# libraries for displaying images
from IPython.display import Image 
from IPython.core.display import HTML 
    
#tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize

# !conda install -c conda-forge folium=0.5.0 --yes
import folium # plotting library
# Out:
# Fetching package metadata .............
# Solving package specifications: .
#
# # All requested packages already installed.
# # packages in environment at /opt/conda/envs/DSX-Python35:
# #
# geopy                     1.18.1                     py_0    conda-forge
# Fetching package metadata .............
# Solving package specifications: .
#
# # All requested packages already installed.
# # packages in environment at /opt/conda/envs/DSX-Python35:
# #
# folium                    0.5.0                      py_0    conda-forge

# %% [markdown]
# ## **Define Foursquare Credentials**

# %%
ClIENT_ID = '4FQQJE2LMGVLERRRE2BOFR1LQQR5ZEHFLTD1WRAFKOFT4TI0' # your Foursquare ID
ClIENT_SECRET = 'RCSNR5TH31NQRG2QYCHK101HRMTUZHBB2TSJ1CJU5UOGRXRQ' # your Foursquare Secret
VERSION = '20180604'
LIMIT =30
print('Your credentails:')
print('Foursquare_ID: ' + ClIENT_ID)
print('Foursquare_Secret:' + ClIENT_SECRET)
# Out:
# Your credentails:
# Foursquare_ID: 4FQQJE2LMGVLERRRE2BOFR1LQQR5ZEHFLTD1WRAFKOFT4TI0
# Foursquare_Secret:RCSNR5TH31NQRG2QYCHK101HRMTUZHBB2TSJ1CJU5UOGRXRQ

# %% [markdown]
# ## **Define the city and get its latitude & longitude**

# %%
# define the city and get its latitude & longitude 
city = 'Toronto'
geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(city)
latitude = location.latitude
longitude = location.longitude
print(latitude, longitude)
# Out:
# 43.653963 -79.387207

# %% [markdown]
# ## **Search for Hotels**

# %%
# search for hotels
search_query = 'Hotel'
radius = 500

# Define the corresponding URL
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'\
.format(ClIENT_ID, ClIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=4FQQJE2LMGVLERRRE2BOFR1LQQR5ZEHFLTD1WRAFKOFT4TI0&client_secret=RCSNR5TH31NQRG2QYCHK101HRMTUZHBB2TSJ1CJU5UOGRXRQ&ll=43.653963,-79.387207&v=20180604&query=Hotel&radius=500&limit=30'

# %%
# Send the GET Request and examine the results
results = requests.get(url).json()
#results

# %%
# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
dataframe = json_normalize(venues)
dataframe.head()
# Out:
#                                           categories  hasPerk  \
# 0  [{'name': 'Hotel', 'primary': True, 'icon': {'...    False
# 1  [{'name': 'Jazz Club', 'primary': True, 'icon'...    False
# 2  [{'name': 'Hotel', 'primary': True, 'icon': {'...    False
# 3  [{'name': 'Hotel', 'primary': True, 'icon': {'...    False
# 4  [{'name': 'Hotel', 'primary': True, 'icon': {'...    False
#
#                          id       location.address location.cc location.city  \
# 0  4ab2d511f964a5209b6c20e3  123 Queen Street West          CA       Toronto
# 1  4b68aed1f964a520de862be3         194 Queen St W          CA       Toronto
# 2  58b7d72dcc05d161570bd712  123 Queen Street West          CA       Toronto
# 3  52ce14b0498e50457ce11780    108 Chestnut Street          CA       Toronto
# 4  4f343a31e4b0230a3b337a90         123 Test Drive          CA       Toronto
#
#   location.country location.crossStreet  location.distance  \
# 0           Canada          at York St.                413
# 1           Canada  Queen & St. Patrick                400
# 2           Canada                  NaN                390
# 3           Canada          Dundas St W                124
# 4           Canada      at somewhere St                500
#
#                            location.formattedAddress  \
# 0  [123 Queen Street West (at York St.), Toronto ...
# 1  [194 Queen St W (Queen & St. Patrick), Toronto...
# 2  [123 Queen Street West, Toronto ON M5H 2M9, Ca...
# 3  [108 Chestnut Street (Dundas St W), Toronto ON...
# 4  [123 Test Drive (at somewhere St), Toronto ON ...
#
#                              location.labeledLatLngs  location.lat  \
# 0  [{'label': 'display', 'lng': -79.3840259313583...     43.651052
# 1  [{'label': 'display', 'lng': -79.3885772338989...     43.650505
# 2  [{'label': 'display', 'lng': -79.3843286, 'lat...     43.651144
# 3  [{'label': 'display', 'lng': -79.3859415, 'lat...     43.654608
# 4  [{'label': 'display', 'lng': -79.387894, 'lat'...     43.658434
#
#    location.lng location.neighborhood location.postalCode location.state  \
# 0    -79.384026                   NaN             M5H 2M9             ON
# 1    -79.388577                   NaN             M5V 1Z1             ON
# 2    -79.384329                   NaN             M5H 2M9             ON
# 3    -79.385942                   NaN             M5G 1R3             ON
# 4    -79.387894                   NaN             M2M 2M2             ON
#
#                                           name    referralId venuePage.id
# 0                Sheraton Centre Toronto Hotel  v-1550348185          NaN
# 1               The Rex Hotel Jazz & Blues Bar  v-1550348185     62225795
# 2                Sheraton Centre Toronto Hotel  v-1550348185    402127087
# 3  DoubleTree by Hilton Hotel Toronto Downtown  v-1550348185          NaN
# 4                               VFM Test Hotel  v-1550348185          NaN

# %% [markdown]
# ## **Clean Hotel Dataframe**

# %%
# keep only columns that include venue name, and anything that is associated with location
clean_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')]+ ['id']
clean_dataframe = dataframe.loc[:,clean_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
clean_dataframe['categories'] = clean_dataframe.apply(get_category_type, axis=1)

# clean column names by keeping only last term
clean_dataframe.columns = [column.split('.')[-1] for column in clean_dataframe.columns]

clean_dataframe.head()
# Out:
#                                           name categories  \
# 0                Sheraton Centre Toronto Hotel      Hotel
# 1               The Rex Hotel Jazz & Blues Bar  Jazz Club
# 2                Sheraton Centre Toronto Hotel      Hotel
# 3  DoubleTree by Hilton Hotel Toronto Downtown      Hotel
# 4                               VFM Test Hotel      Hotel
#
#                  address  cc     city country          crossStreet  distance  \
# 0  123 Queen Street West  CA  Toronto  Canada          at York St.       413
# 1         194 Queen St W  CA  Toronto  Canada  Queen & St. Patrick       400
# 2  123 Queen Street West  CA  Toronto  Canada                  NaN       390
# 3    108 Chestnut Street  CA  Toronto  Canada          Dundas St W       124
# 4         123 Test Drive  CA  Toronto  Canada      at somewhere St       500
#
#                                     formattedAddress  \
# 0  [123 Queen Street West (at York St.), Toronto ...
# 1  [194 Queen St W (Queen & St. Patrick), Toronto...
# 2  [123 Queen Street West, Toronto ON M5H 2M9, Ca...
# 3  [108 Chestnut Street (Dundas St W), Toronto ON...
# 4  [123 Test Drive (at somewhere St), Toronto ON ...
#
#                                       labeledLatLngs        lat        lng  \
# 0  [{'label': 'display', 'lng': -79.3840259313583...  43.651052 -79.384026
# 1  [{'label': 'display', 'lng': -79.3885772338989...  43.650505 -79.388577
# 2  [{'label': 'display', 'lng': -79.3843286, 'lat...  43.651144 -79.384329
# 3  [{'label': 'display', 'lng': -79.3859415, 'lat...  43.654608 -79.385942
# 4  [{'label': 'display', 'lng': -79.387894, 'lat'...  43.658434 -79.387894
#
#   neighborhood postalCode state                        id
# 0          NaN    M5H 2M9    ON  4ab2d511f964a5209b6c20e3
# 1          NaN    M5V 1Z1    ON  4b68aed1f964a520de862be3
# 2          NaN    M5H 2M9    ON  58b7d72dcc05d161570bd712
# 3          NaN    M5G 1R3    ON  52ce14b0498e50457ce11780
# 4          NaN    M2M 2M2    ON  4f343a31e4b0230a3b337a90

# %%
# delete unnecessary columns
clean_dataframe2= clean_dataframe.drop(['cc', 'city', 'country', 'crossStreet', 'distance', 'formattedAddress',\
                                        'labeledLatLngs','neighborhood', 'id'], axis=1)
clean_dataframe2
# Out:
#                                               name              categories  \
# 0                    Sheraton Centre Toronto Hotel                   Hotel
# 1                   The Rex Hotel Jazz & Blues Bar               Jazz Club
# 2                    Sheraton Centre Toronto Hotel                   Hotel
# 3      DoubleTree by Hilton Hotel Toronto Downtown                   Hotel
# 4                                   VFM Test Hotel                   Hotel
# 5   Sheraton Centre Toronto Hotel - Grand Ballroom                Ballroom
# 6                                  Stathcona Hotel                   Hotel
# 7    hilton hotel, richmondstreet E, 145,  toronto              Hotel Pool
# 8                                Be SixFifty Hotel                   Hotel
# 9                                        650 Hotel                   Hotel
# 10                           89 Chestnut Residence  College Residence Hall
# 11                                  Hilton Toronto                   Hotel
# 12                   Op mijn hotelkamer In Toronto                   Hotel
# 13          Lobby Lounge at the Shangri-La Toronto                  Lounge
# 14    Marriott Downtown at CF Toronto Eaton Centre                   Hotel
# 15                              Shangri-La Toronto                   Hotel
# 16                                  Fitness Centre                     Gym
# 17                                  Fitness Centre                     Gym
# 18                                            Pool                    Pool
# 19                                   Kumar For Men             Men's Store
# 20                                   Bistro on Two          Breakfast Spot
# 21                                  Grand Ballroom             Event Space
#
#                      address        lat        lng postalCode    state
# 0      123 Queen Street West  43.651052 -79.384026    M5H 2M9       ON
# 1             194 Queen St W  43.650505 -79.388577    M5V 1Z1       ON
# 2      123 Queen Street West  43.651144 -79.384329    M5H 2M9       ON
# 3        108 Chestnut Street  43.654608 -79.385942    M5G 1R3       ON
# 4             123 Test Drive  43.658434 -79.387894    M2M 2M2       ON
# 5      123 Queen Street West  43.651200 -79.384520        NaN       ON
# 6                        NaN  43.654947 -79.386359        NaN       ON
# 7      Richmondstreet E, 145  43.650625 -79.385488        NaN       ON
# 8             650 Bay Street  43.657120 -79.384560        NaN       ON
# 9             650 Bay Street  43.657046 -79.384411        NaN       ON
# 10           89 Chestnut St.  43.654160 -79.385291    M5G 1R1       ON
# 11  145 Richmond Street West  43.649852 -79.385576    M5H 2L2       ON
# 12                       NaN  43.654235 -79.386208        NaN       ON
# 13       188 University Ave.  43.649155 -79.386546    M5H 0A3       ON
# 14            525 Bay Street  43.654728 -79.382422    M5G 2L2       ON
# 15       188 University Ave.  43.649129 -79.386557    M5H 0A3       ON
# 16           Sheraton Centre  43.650985 -79.384002    M5H 2M9       ON
# 17               525 Bay St.  43.654690 -79.381739    M5G 2L2       ON
# 18          Intercontinental  43.650975 -79.384053        NaN  Ontario
# 19           Sheraton Centre  43.651044 -79.383302    M5H 2M9       ON
# 20           123 Queen St. W  43.651011 -79.383658    M5H 2M9       ON
# 21           123 Queen St. W  43.651217 -79.383771    M5H 2M9       ON

# %%
# delete rows with none values
clean_dataframe3 = clean_dataframe2.dropna(axis=0, how='any', thresh=None, subset=None, inplace=False)
clean_dataframe3
# Out:
#                                             name              categories  \
# 0                  Sheraton Centre Toronto Hotel                   Hotel
# 1                 The Rex Hotel Jazz & Blues Bar               Jazz Club
# 2                  Sheraton Centre Toronto Hotel                   Hotel
# 3    DoubleTree by Hilton Hotel Toronto Downtown                   Hotel
# 4                                 VFM Test Hotel                   Hotel
# 10                         89 Chestnut Residence  College Residence Hall
# 11                                Hilton Toronto                   Hotel
# 13        Lobby Lounge at the Shangri-La Toronto                  Lounge
# 14  Marriott Downtown at CF Toronto Eaton Centre                   Hotel
# 15                            Shangri-La Toronto                   Hotel
# 16                                Fitness Centre                     Gym
# 17                                Fitness Centre                     Gym
# 19                                 Kumar For Men             Men's Store
# 20                                 Bistro on Two          Breakfast Spot
# 21                                Grand Ballroom             Event Space
#
#                      address        lat        lng postalCode state
# 0      123 Queen Street West  43.651052 -79.384026    M5H 2M9    ON
# 1             194 Queen St W  43.650505 -79.388577    M5V 1Z1    ON
# 2      123 Queen Street West  43.651144 -79.384329    M5H 2M9    ON
# 3        108 Chestnut Street  43.654608 -79.385942    M5G 1R3    ON
# 4             123 Test Drive  43.658434 -79.387894    M2M 2M2    ON
# 10           89 Chestnut St.  43.654160 -79.385291    M5G 1R1    ON
# 11  145 Richmond Street West  43.649852 -79.385576    M5H 2L2    ON
# 13       188 University Ave.  43.649155 -79.386546    M5H 0A3    ON
# 14            525 Bay Street  43.654728 -79.382422    M5G 2L2    ON
# 15       188 University Ave.  43.649129 -79.386557    M5H 0A3    ON
# 16           Sheraton Centre  43.650985 -79.384002    M5H 2M9    ON
# 17               525 Bay St.  43.654690 -79.381739    M5G 2L2    ON
# 19           Sheraton Centre  43.651044 -79.383302    M5H 2M9    ON
# 20           123 Queen St. W  43.651011 -79.383658    M5H 2M9    ON
# 21           123 Queen St. W  43.651217 -79.383771    M5H 2M9    ON

# %%
# delete rows which its category is not Hotel or Event Space
array= ['Hotel', 'Event Space']
hotel_dataframe= clean_dataframe3.loc[clean_dataframe3['categories'].isin(array)]
hotel_dataframe
# Out:
#                                             name   categories  \
# 0                  Sheraton Centre Toronto Hotel        Hotel
# 2                  Sheraton Centre Toronto Hotel        Hotel
# 3    DoubleTree by Hilton Hotel Toronto Downtown        Hotel
# 4                                 VFM Test Hotel        Hotel
# 11                                Hilton Toronto        Hotel
# 14  Marriott Downtown at CF Toronto Eaton Centre        Hotel
# 15                            Shangri-La Toronto        Hotel
# 21                                Grand Ballroom  Event Space
#
#                      address        lat        lng postalCode state
# 0      123 Queen Street West  43.651052 -79.384026    M5H 2M9    ON
# 2      123 Queen Street West  43.651144 -79.384329    M5H 2M9    ON
# 3        108 Chestnut Street  43.654608 -79.385942    M5G 1R3    ON
# 4             123 Test Drive  43.658434 -79.387894    M2M 2M2    ON
# 11  145 Richmond Street West  43.649852 -79.385576    M5H 2L2    ON
# 14            525 Bay Street  43.654728 -79.382422    M5G 2L2    ON
# 15       188 University Ave.  43.649129 -79.386557    M5H 0A3    ON
# 21           123 Queen St. W  43.651217 -79.383771    M5H 2M9    ON

# %%
# delete rows which has duplicate hotel's name
df_hotels = hotel_dataframe.drop_duplicates(subset='name', keep="first")
df_hotels
# Out:
#                                             name   categories  \
# 0                  Sheraton Centre Toronto Hotel        Hotel
# 3    DoubleTree by Hilton Hotel Toronto Downtown        Hotel
# 4                                 VFM Test Hotel        Hotel
# 11                                Hilton Toronto        Hotel
# 14  Marriott Downtown at CF Toronto Eaton Centre        Hotel
# 15                            Shangri-La Toronto        Hotel
# 21                                Grand Ballroom  Event Space
#
#                      address        lat        lng postalCode state
# 0      123 Queen Street West  43.651052 -79.384026    M5H 2M9    ON
# 3        108 Chestnut Street  43.654608 -79.385942    M5G 1R3    ON
# 4             123 Test Drive  43.658434 -79.387894    M2M 2M2    ON
# 11  145 Richmond Street West  43.649852 -79.385576    M5H 2L2    ON
# 14            525 Bay Street  43.654728 -79.382422    M5G 2L2    ON
# 15       188 University Ave.  43.649129 -79.386557    M5H 0A3    ON
# 21           123 Queen St. W  43.651217 -79.383771    M5H 2M9    ON

# %%
# choose the hotel which has the same postalCode with the event space
df_hotel = df_hotels[df_hotels.postalCode == 'M5H 2M9']
df_hotel
# Out:
#                              name   categories                address  \
# 0   Sheraton Centre Toronto Hotel        Hotel  123 Queen Street West
# 21                 Grand Ballroom  Event Space        123 Queen St. W
#
#           lat        lng postalCode state
# 0   43.651052 -79.384026    M5H 2M9    ON
# 21  43.651217 -79.383771    M5H 2M9    ON

# %% [markdown]
# ## **Search for Parks**

# %%
# search for Parks
search_query = 'Park'
radius = 10000

# Define the corresponding URL
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'\
.format(ClIENT_ID, ClIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=4FQQJE2LMGVLERRRE2BOFR1LQQR5ZEHFLTD1WRAFKOFT4TI0&client_secret=RCSNR5TH31NQRG2QYCHK101HRMTUZHBB2TSJ1CJU5UOGRXRQ&ll=43.653963,-79.387207&v=20180604&query=Park&radius=10000&limit=30'

# %%
# Send the GET Request and examine the results
presults = requests.get(url).json()
#presults

# %%
# assign relevant part of JSON to venues
venues = presults['response']['venues']

# tranform venues into a dataframe
park_dataframe = json_normalize(venues)
park_dataframe.head()
# Out:
#                                           categories  hasPerk  \
# 0  [{'name': 'Metro Station', 'primary': True, 'i...    False
# 1  [{'name': 'Park', 'primary': True, 'icon': {'s...    False
# 2  [{'name': 'Park', 'primary': True, 'icon': {'s...    False
# 3  [{'name': 'Residential Building (Apartment / C...    False
# 4  [{'name': 'Park', 'primary': True, 'icon': {'s...    False
#
#                          id    location.address location.cc location.city  \
# 0  4b170e47f964a5208cc123e3  691 University Ave          CA       Toronto
# 1  4b54deadf964a520a3d027e3                 NaN          CA       Toronto
# 2  4bb3c91a2397b7134d9f38b3         Spadina Ave          CA       Toronto
# 3  4ad80fcef964a520a61021e3       280 Simcoe St          CA       Toronto
# 4  4b9d206bf964a520e69136e3     University Ave.          CA       Toronto
#
#   location.country location.crossStreet  location.distance  \
# 0           Canada        at College St                716
# 1           Canada                  NaN                423
# 2           Canada   at Wellington St W               1223
# 3           Canada   Dundas Street West                282
# 4           Canada    at Wellesley Ave.               1181
#
#                            location.formattedAddress  \
# 0  [691 University Ave (at College St), Toronto O...
# 1  [btwn College, University, Queen & Spadina, To...
# 2  [Spadina Ave (at Wellington St W), Toronto ON,...
# 3  [280 Simcoe St (Dundas Street West), Toronto O...
# 4  [University Ave. (at Wellesley Ave.), Toronto ...
#
#                              location.labeledLatLngs  location.lat  \
# 0  [{'label': 'display', 'lng': -79.3902722022604...     43.660006
# 1  [{'label': 'display', 'lng': -79.3920530754014...     43.652488
# 2  [{'label': 'display', 'lng': -79.3942301870698...     43.644222
# 3  [{'label': 'display', 'lng': -79.3900562278751...     43.655442
# 4  [{'label': 'display', 'lng': -79.3921795252083...     43.663946
#
#    location.lng location.postalCode location.state  \
# 0    -79.390272             M5G 2P1             ON
# 1    -79.392053                 NaN             ON
# 2    -79.394230                 NaN             ON
# 3    -79.390056             M5T 2Y5             ON
# 4    -79.392180             M5R 2E8             ON
#
#                           name    referralId venuePage.id
# 0  Queen's Park Subway Station  v-1550348274          NaN
# 1                  Grange Park  v-1550348274          NaN
# 2         Clarence Square Park  v-1550348274          NaN
# 3                One Park Lane  v-1550348274          NaN
# 4                 Queen's Park  v-1550348274          NaN

# %% [markdown]
# ## **Clean Park Dataframe**

# %%
# keep only columns that include venue name, and anything that is associated with location
park_clean_columns = ['name', 'categories'] + [col for col in park_dataframe.columns if col.startswith('location.')]+ ['id']
clean_park_dataframe = park_dataframe.loc[:,park_clean_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list1 = row['categories']
    except:
        categories_list1 = row['venue.categories']
        
    if len(categories_list1) == 0:
        return None
    else:
        return categories_list1[0]['name']

# filter the category for each row
clean_park_dataframe['categories'] = clean_park_dataframe.apply(get_category_type, axis=1)

# clean column names by keeping only last term
clean_park_dataframe.columns = [column.split('.')[-1] for column in clean_park_dataframe.columns]

clean_park_dataframe.head()
# Out:
#                           name                                categories  \
# 0  Queen's Park Subway Station                             Metro Station
# 1                  Grange Park                                      Park
# 2         Clarence Square Park                                      Park
# 3                One Park Lane  Residential Building (Apartment / Condo)
# 4                 Queen's Park                                      Park
#
#               address  cc     city country         crossStreet  distance  \
# 0  691 University Ave  CA  Toronto  Canada       at College St       716
# 1                 NaN  CA  Toronto  Canada                 NaN       423
# 2         Spadina Ave  CA  Toronto  Canada  at Wellington St W      1223
# 3       280 Simcoe St  CA  Toronto  Canada  Dundas Street West       282
# 4     University Ave.  CA  Toronto  Canada   at Wellesley Ave.      1181
#
#                                     formattedAddress  \
# 0  [691 University Ave (at College St), Toronto O...
# 1  [btwn College, University, Queen & Spadina, To...
# 2  [Spadina Ave (at Wellington St W), Toronto ON,...
# 3  [280 Simcoe St (Dundas Street West), Toronto O...
# 4  [University Ave. (at Wellesley Ave.), Toronto ...
#
#                                       labeledLatLngs        lat        lng  \
# 0  [{'label': 'display', 'lng': -79.3902722022604...  43.660006 -79.390272
# 1  [{'label': 'display', 'lng': -79.3920530754014...  43.652488 -79.392053
# 2  [{'label': 'display', 'lng': -79.3942301870698...  43.644222 -79.394230
# 3  [{'label': 'display', 'lng': -79.3900562278751...  43.655442 -79.390056
# 4  [{'label': 'display', 'lng': -79.3921795252083...  43.663946 -79.392180
#
#   postalCode state                        id
# 0    M5G 2P1    ON  4b170e47f964a5208cc123e3
# 1        NaN    ON  4b54deadf964a520a3d027e3
# 2        NaN    ON  4bb3c91a2397b7134d9f38b3
# 3    M5T 2Y5    ON  4ad80fcef964a520a61021e3
# 4    M5R 2E8    ON  4b9d206bf964a520e69136e3

# %%
# delete unnecessary columns
clean_park_dataframe2= clean_park_dataframe.drop(['cc', 'city', 'country', 'crossStreet', 'distance', 'formattedAddress',\
                                        'labeledLatLngs', 'id'], axis=1)
clean_park_dataframe2
# Out:
#                                    name  \
# 0           Queen's Park Subway Station
# 1                           Grange Park
# 2                  Clarence Square Park
# 3                         One Park Lane
# 4                          Queen's Park
# 5     St. Andrews Playground / Dog Park
# 6                           Berczy Park
# 7                Trinity Bellwoods Park
# 8                Parliament Square Park
# 9   GoodLife Fitness Toronto Bloor Park
# 10                             HTO Park
# 11     Residences at College Park North
# 12     Toothworks - College Park Dental
# 13   TTC Streetcar #403 - Victoria park
# 14        Crunch Fitness - College Park
# 15              Cawthra Square Dog Park
# 16                 Bellevue Square Park
# 17                  Riverdale Park West
# 18         Victoria Park Subway Station
# 19                   Battery Park Tower
# 20                  Riverdale Park East
# 21                    Barbara Hall Park
# 22              Stanley Park (Dog Park)
# 23                      Winchester Park
# 24                            High Park
# 25            Village of Yorkville Park
# 26                   Canoe Landing Park
# 27                          Regent Park
# 28           Sir Winston Churchill Park
# 29                      Coronation Park
#
#                                   categories                       address  \
# 0                              Metro Station            691 University Ave
# 1                                       Park                           NaN
# 2                                       Park                   Spadina Ave
# 3   Residential Building (Apartment / Condo)                 280 Simcoe St
# 4                                       Park               University Ave.
# 5                                       Park      450 Adelaide Street West
# 6                                       Park        35 Wellington St. East
# 7                                       Park            1053 Dundas St. W.
# 8                                       Park          44 Parliament Street
# 9                                        Gym                     8 Park Rd
# 10                                      Park                  Queen's Quay
# 11  Residential Building (Apartment / Condo)                   763 Bay St.
# 12                          Dentist's Office        444 Yonge St, Unit M16
# 13                        Light Rail Station                           NaN
# 14                      Gym / Fitness Center              382 Yonge Street
# 15                                   Dog Run                519 Church St.
# 16                                      Park  btwn Bellevue & Augusta Ave.
# 17                                      Park               500 Gerrard St.
# 18                             Metro Station         777 Victoria Park Ave
# 19  Residential Building (Apartment / Condo)           50 Lynn Williams St
# 20                                      Park             550 Broadview Ave
# 21                                      Park                 519 Church St
# 22                                   Dog Run              King Street West
# 23                                Playground            530 Ontario Street
# 24                                      Park              1873 Bloor St. W
# 25                                      Park            115 Cumberland St.
# 26                                      Park             50 Fort York Blvd
# 27                                      Park              620 Dundas St E.
# 28                                      Park            301 St Clair Ave W
# 29                                      Park        711 Lake Shore Blvd. W
#
#           lat        lng postalCode state
# 0   43.660006 -79.390272    M5G 2P1    ON
# 1   43.652488 -79.392053        NaN    ON
# 2   43.644222 -79.394230        NaN    ON
# 3   43.655442 -79.390056    M5T 2Y5    ON
# 4   43.663946 -79.392180    M5R 2E8    ON
# 5   43.647388 -79.398752        NaN    ON
# 6   43.648048 -79.375172        NaN    ON
# 7   43.647072 -79.413756    M5H 2N2    ON
# 8   43.650264 -79.362195        NaN    ON
# 9   43.671398 -79.384408    M4W 3G8    ON
# 10  43.637949 -79.387820        NaN    ON
# 11  43.659822 -79.385159    M5G 2R3    ON
# 12  43.660009 -79.383905        NaN    ON
# 13  43.650735 -79.386921        NaN    ON
# 14  43.659263 -79.382632    M5G 1S8    ON
# 15  43.666583 -79.380040        NaN    ON
# 16  43.653610 -79.402199    M5T 2N4    ON
# 17  43.666048 -79.360941    M5A 2H3    ON
# 18  43.694883 -79.288735    M4B 2E2    ON
# 19  43.639024 -79.415510    M6K 3R9    ON
# 20  43.669951 -79.355493    M4K 2P1    ON
# 21  43.666879 -79.381068    M4Y 2K9    ON
# 22  43.641668 -79.409269        NaN    ON
# 23  43.666231 -79.371631        NaN    ON
# 24  43.646479 -79.463425    M6R 2Z3    ON
# 25  43.670186 -79.391180        NaN    ON
# 26  43.638762 -79.397067    M5V 3Z1    ON
# 27  43.660383 -79.361810        NaN    ON
# 28  43.683732 -79.409881    M4V 1S4    ON
# 29  43.634553 -79.405403    M5V 3T7    ON

# %%
# delete rows with none values
clean_park_dataframe3 = clean_park_dataframe2.dropna(axis=0, how='any', thresh=None, subset=None, inplace=False)
clean_park_dataframe3
# Out:
#                                    name  \
# 0           Queen's Park Subway Station
# 3                         One Park Lane
# 4                          Queen's Park
# 7                Trinity Bellwoods Park
# 9   GoodLife Fitness Toronto Bloor Park
# 11     Residences at College Park North
# 14        Crunch Fitness - College Park
# 16                 Bellevue Square Park
# 17                  Riverdale Park West
# 18         Victoria Park Subway Station
# 19                   Battery Park Tower
# 20                  Riverdale Park East
# 21                    Barbara Hall Park
# 24                            High Park
# 26                   Canoe Landing Park
# 28           Sir Winston Churchill Park
# 29                      Coronation Park
#
#                                   categories                       address  \
# 0                              Metro Station            691 University Ave
# 3   Residential Building (Apartment / Condo)                 280 Simcoe St
# 4                                       Park               University Ave.
# 7                                       Park            1053 Dundas St. W.
# 9                                        Gym                     8 Park Rd
# 11  Residential Building (Apartment / Condo)                   763 Bay St.
# 14                      Gym / Fitness Center              382 Yonge Street
# 16                                      Park  btwn Bellevue & Augusta Ave.
# 17                                      Park               500 Gerrard St.
# 18                             Metro Station         777 Victoria Park Ave
# 19  Residential Building (Apartment / Condo)           50 Lynn Williams St
# 20                                      Park             550 Broadview Ave
# 21                                      Park                 519 Church St
# 24                                      Park              1873 Bloor St. W
# 26                                      Park             50 Fort York Blvd
# 28                                      Park            301 St Clair Ave W
# 29                                      Park        711 Lake Shore Blvd. W
#
#           lat        lng postalCode state
# 0   43.660006 -79.390272    M5G 2P1    ON
# 3   43.655442 -79.390056    M5T 2Y5    ON
# 4   43.663946 -79.392180    M5R 2E8    ON
# 7   43.647072 -79.413756    M5H 2N2    ON
# 9   43.671398 -79.384408    M4W 3G8    ON
# 11  43.659822 -79.385159    M5G 2R3    ON
# 14  43.659263 -79.382632    M5G 1S8    ON
# 16  43.653610 -79.402199    M5T 2N4    ON
# 17  43.666048 -79.360941    M5A 2H3    ON
# 18  43.694883 -79.288735    M4B 2E2    ON
# 19  43.639024 -79.415510    M6K 3R9    ON
# 20  43.669951 -79.355493    M4K 2P1    ON
# 21  43.666879 -79.381068    M4Y 2K9    ON
# 24  43.646479 -79.463425    M6R 2Z3    ON
# 26  43.638762 -79.397067    M5V 3Z1    ON
# 28  43.683732 -79.409881    M4V 1S4    ON
# 29  43.634553 -79.405403    M5V 3T7    ON

# %%
# delete rows which its category is not Park
df_park = clean_park_dataframe3[clean_park_dataframe3.categories == 'Park']
df_park
# Out:
#                           name categories                       address  \
# 4                 Queen's Park       Park               University Ave.
# 7       Trinity Bellwoods Park       Park            1053 Dundas St. W.
# 16        Bellevue Square Park       Park  btwn Bellevue & Augusta Ave.
# 17         Riverdale Park West       Park               500 Gerrard St.
# 20         Riverdale Park East       Park             550 Broadview Ave
# 21           Barbara Hall Park       Park                 519 Church St
# 24                   High Park       Park              1873 Bloor St. W
# 26          Canoe Landing Park       Park             50 Fort York Blvd
# 28  Sir Winston Churchill Park       Park            301 St Clair Ave W
# 29             Coronation Park       Park        711 Lake Shore Blvd. W
#
#           lat        lng postalCode state
# 4   43.663946 -79.392180    M5R 2E8    ON
# 7   43.647072 -79.413756    M5H 2N2    ON
# 16  43.653610 -79.402199    M5T 2N4    ON
# 17  43.666048 -79.360941    M5A 2H3    ON
# 20  43.669951 -79.355493    M4K 2P1    ON
# 21  43.666879 -79.381068    M4Y 2K9    ON
# 24  43.646479 -79.463425    M6R 2Z3    ON
# 26  43.638762 -79.397067    M5V 3Z1    ON
# 28  43.683732 -79.409881    M4V 1S4    ON
# 29  43.634553 -79.405403    M5V 3T7    ON

# %% [markdown]
# ## **Search for Restaurants**

# %%
# search for Restaurants
search_query = 'Restaurant'
radius = 10000

# Define the corresponding URL
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(ClIENT_ID, ClIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=4FQQJE2LMGVLERRRE2BOFR1LQQR5ZEHFLTD1WRAFKOFT4TI0&client_secret=RCSNR5TH31NQRG2QYCHK101HRMTUZHBB2TSJ1CJU5UOGRXRQ&ll=43.653963,-79.387207&v=20180604&query=Restaurant&radius=10000&limit=30'

# %%
# Send the GET Request and examine the results
Rresults = requests.get(url).json()
#Rresults

# %%
# assign relevant part of JSON to venues
venues = Rresults['response']['venues']

# tranform venues into a dataframe
Restaurant_dataframe = json_normalize(venues)
Restaurant_dataframe.head()
# Out:
#                                           categories  hasPerk  \
# 0  [{'name': 'American Restaurant', 'primary': Tr...    False
# 1  [{'name': 'Restaurant', 'primary': True, 'icon...    False
# 2  [{'name': 'Dim Sum Restaurant', 'primary': Tru...    False
# 3  [{'name': 'Wine Bar', 'primary': True, 'icon':...    False
# 4  [{'name': 'Chinese Restaurant', 'primary': Tru...    False
#
#                          id     location.address location.cc location.city  \
# 0  4ad4c05ff964a52048f720e3  110 Chestnut Street          CA       Toronto
# 1  4baa4b39f964a520ec5b3ae3          181 Bay St.          CA       Toronto
# 2  4ad4c060f964a5207ff720e3     323 Spadina Ave.          CA       Toronto
# 3  4ad4c05cf964a520dff520e3       301 Front St W          CA       Toronto
# 4  4ae29812f964a520288f21e3     309 Spadina Ave.          CA       Toronto
#
#   location.country            location.crossStreet  location.distance  \
# 0           Canada                             NaN                145
# 1           Canada             in Brookfield Place               1077
# 2           Canada                   at D'Arcy St.                922
# 3           Canada                 301 Front St. W               1271
# 4           Canada  btwn Dundas St. W & D'Arcy St.                896
#
#                            location.formattedAddress  \
# 0  [110 Chestnut Street, Toronto ON M5G 1R3, Canada]
# 1  [181 Bay St. (in Brookfield Place), Toronto ON...
# 2  [323 Spadina Ave. (at D'Arcy St.), Toronto ON ...
# 3  [301 Front St W (301 Front St. W), Toronto ON ...
# 4  [309 Spadina Ave. (btwn Dundas St. W & D'Arcy ...
#
#                              location.labeledLatLngs  location.lat  \
# 0  [{'label': 'display', 'lng': -79.3859307737157...     43.654884
# 1  [{'label': 'display', 'lng': -79.3775911908116...     43.647232
# 2  [{'label': 'display', 'lng': -79.3986499837468...     43.654318
# 3  [{'label': 'display', 'lng': -79.3870420156932...     43.642537
# 4  [{'label': 'display', 'lng': -79.3983335333920...     43.653866
#
#    location.lng location.neighborhood location.postalCode location.state  \
# 0    -79.385931                   NaN             M5G 1R3             ON
# 1    -79.377591                   NaN             M5J 2T3             ON
# 2    -79.398650     Kensington Market             M5T 2E9             ON
# 3    -79.387042                   NaN             M5V 2T6             ON
# 4    -79.398334                   NaN             M5T 2E6             ON
#
#                               name    referralId venuePage.id
# 0  Hemispheres Restaurant & Bistro  v-1550348335          NaN
# 1                Marché Restaurant  v-1550348335     59869170
# 2           Rol San Restaurant 龍笙棧  v-1550348335          NaN
# 3                   360 Restaurant  v-1550348335          NaN
# 4          Swatow Restaurant 汕頭小食家  v-1550348335          NaN

# %% [markdown]
# ## **Clean Restaurant Dataframe**

# %%
# keep only columns that include venue name, and anything that is associated with location
Restaurant_clean_columns = ['name', 'categories'] + [col for col in Restaurant_dataframe.columns if col.startswith('location.')]+ ['id']
clean_Restaurant_dataframe = Restaurant_dataframe.loc[:,Restaurant_clean_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list3 = row['categories']
    except:
        categories_list3 = row['venue.categories']
        
    if len(categories_list3) == 0:
        return None
    else:
        return categories_list3[0]['name']

# filter the category for each row
clean_Restaurant_dataframe['categories'] = clean_Restaurant_dataframe.apply(get_category_type, axis=1)

# clean column names by keeping only last term
clean_Restaurant_dataframe.columns = [column.split('.')[-1] for column in clean_Restaurant_dataframe.columns]

clean_Restaurant_dataframe.head()
# Out:
#                               name           categories              address  \
# 0  Hemispheres Restaurant & Bistro  American Restaurant  110 Chestnut Street
# 1                Marché Restaurant           Restaurant          181 Bay St.
# 2           Rol San Restaurant 龍笙棧   Dim Sum Restaurant     323 Spadina Ave.
# 3                   360 Restaurant             Wine Bar       301 Front St W
# 4          Swatow Restaurant 汕頭小食家   Chinese Restaurant     309 Spadina Ave.
#
#    cc     city country                     crossStreet  distance  \
# 0  CA  Toronto  Canada                             NaN       145
# 1  CA  Toronto  Canada             in Brookfield Place      1077
# 2  CA  Toronto  Canada                   at D'Arcy St.       922
# 3  CA  Toronto  Canada                 301 Front St. W      1271
# 4  CA  Toronto  Canada  btwn Dundas St. W & D'Arcy St.       896
#
#                                     formattedAddress  \
# 0  [110 Chestnut Street, Toronto ON M5G 1R3, Canada]
# 1  [181 Bay St. (in Brookfield Place), Toronto ON...
# 2  [323 Spadina Ave. (at D'Arcy St.), Toronto ON ...
# 3  [301 Front St W (301 Front St. W), Toronto ON ...
# 4  [309 Spadina Ave. (btwn Dundas St. W & D'Arcy ...
#
#                                       labeledLatLngs        lat        lng  \
# 0  [{'label': 'display', 'lng': -79.3859307737157...  43.654884 -79.385931
# 1  [{'label': 'display', 'lng': -79.3775911908116...  43.647232 -79.377591
# 2  [{'label': 'display', 'lng': -79.3986499837468...  43.654318 -79.398650
# 3  [{'label': 'display', 'lng': -79.3870420156932...  43.642537 -79.387042
# 4  [{'label': 'display', 'lng': -79.3983335333920...  43.653866 -79.398334
#
#         neighborhood postalCode state                        id
# 0                NaN    M5G 1R3    ON  4ad4c05ff964a52048f720e3
# 1                NaN    M5J 2T3    ON  4baa4b39f964a520ec5b3ae3
# 2  Kensington Market    M5T 2E9    ON  4ad4c060f964a5207ff720e3
# 3                NaN    M5V 2T6    ON  4ad4c05cf964a520dff520e3
# 4                NaN    M5T 2E6    ON  4ae29812f964a520288f21e3

# %%
# delete unnecessary columns
clean_Restaurant_dataframe2= clean_Restaurant_dataframe.drop(['cc', 'city', 'country', 'crossStreet', 'distance', 'formattedAddress',\
                                        'labeledLatLngs', 'neighborhood', 'id'], axis=1)
clean_Restaurant_dataframe2
# Out:
#                                               name               categories  \
# 0                  Hemispheres Restaurant & Bistro      American Restaurant
# 1                                Marché Restaurant               Restaurant
# 2                           Rol San Restaurant 龍笙棧       Dim Sum Restaurant
# 3                                   360 Restaurant                 Wine Bar
# 4                          Swatow Restaurant 汕頭小食家       Chinese Restaurant
# 5                   Goldstone Noodle Restaurant 金石             Noodle House
# 6                            Victoria's Restaurant               Restaurant
# 7               Sky Dragon Chinese Restaurant 龍翔酒樓       Dim Sum Restaurant
# 8                         New Sky Restaurant 小沙田食家       Chinese Restaurant
# 9                   The Hot House Restaurant & Bar      American Restaurant
# 10                    Aroma Fine Indian Restaurant        Indian Restaurant
# 11                          Azure Restaurant & Bar               Restaurant
# 12  Sassafraz | Cafe | Restaurant | Private Events              Event Space
# 13             Richtree Natural Market Restaurants               Restaurant
# 14                         Victor Restaurant & Bar                      Bar
# 15              North-East Chinese Restaurant 華北美食       Chinese Restaurant
# 16                  Insomnia Restaurant and Lounge               Restaurant
# 17         Tasty's Caribbean Restaurant & Catering     Caribbean Restaurant
# 18                           ONE Restaurant/Lounge  New American Restaurant
# 19                 Bright Pearl Seafood Restaurant       Chinese Restaurant
# 20                         The Lakeview Restaurant                    Diner
# 21                   Hong Shing Chinese Restaurant       Chinese Restaurant
# 22                    Yueh Tung Chinese Restaurant       Chinese Restaurant
# 23                 Kyoto House Japanese Restaurant         Sushi Restaurant
# 24                        Ka Chi Korean Restaurant        Korean Restaurant
# 25               Kensington Cornerstone Restaurant           Breakfast Spot
# 26                               Tundra Restaurant               Restaurant
# 27                     Woodlot Restaurant & Bakery  New American Restaurant
# 28                               Studio Restaurant           Breakfast Spot
# 29               El Rancho Restaurant & Night Club                Nightclub
#
#                      address        lat        lng postalCode state
# 0        110 Chestnut Street  43.654884 -79.385931    M5G 1R3    ON
# 1                181 Bay St.  43.647232 -79.377591    M5J 2T3    ON
# 2           323 Spadina Ave.  43.654318 -79.398650    M5T 2E9    ON
# 3             301 Front St W  43.642537 -79.387042    M5V 2T6    ON
# 4           309 Spadina Ave.  43.653866 -79.398334    M5T 2E6    ON
# 5            266 Spadina Ave  43.652278 -79.398039    M5T 2E4    ON
# 6        37 King Street East  43.649298 -79.376431    M5C 1E9    ON
# 7           280 Spadina Ave.  43.652783 -79.398174        NaN    ON
# 8           353 Spadina Ave.  43.655337 -79.398897    M5T 2G3    ON
# 9               35 Church St  43.648683 -79.373741    M5E 1T3    ON
# 10            287 King St. W  43.646463 -79.389644    M5V 1J5    ON
# 11             225 Frnt St W  43.644749 -79.385113    M5V 2X3    ON
# 12     100 Cumberland Street  43.670342 -79.391041    M5R 1A6    ON
# 13             14 Queen St W  43.652614 -79.380231    M5H 3X4    ON
# 14          30 Mercer Street  43.645634 -79.391125    M5V 1H3    ON
# 15            476 Dundas St.  43.653185 -79.396677        NaN    ON
# 16         563 Bloor St West  43.665180 -79.410966    M5S 1Y6    ON
# 17           405 Spadina Ave  43.656794 -79.399251    M5T 2G6    ON
# 18         116 Yorkville Ave  43.670809 -79.393272        NaN    ON
# 19    346-348 Spadina Avenue  43.654219 -79.399125    M5T 2G2    ON
# 20         1132 Dundas St. W  43.649435 -79.420390    M6J 1X2    ON
# 21           195 Dundas St W  43.654925 -79.387089    M5G 1C7    ON
# 22         126 Elizabeth St.  43.655281 -79.385337        NaN    ON
# 23       143 Dundas St. West  43.655381 -79.385270        NaN    ON
# 24           8 St Andrew St.  43.654307 -79.399277    M5T 1K6    ON
# 25        2A Kensington Ave.  43.652803 -79.399958    M5T 2J7    ON
# 26  145 Richmond Street West  43.650010 -79.385608    M5H 2L2    ON
# 27       293 Palmerston Ave.  43.655765 -79.409929    M6J 2J3    ON
# 28            389 Church St.  43.661500 -79.379319        M5B    ON
# 29           430 College St.  43.656673 -79.407101    M5T 1T3    ON

# %%
# delete rows with none values
df_Restaurant = clean_Restaurant_dataframe2.dropna(axis=0, how='any', thresh=None, subset=None, inplace=False)
df_Restaurant
# Out:
#                                               name               categories  \
# 0                  Hemispheres Restaurant & Bistro      American Restaurant
# 1                                Marché Restaurant               Restaurant
# 2                           Rol San Restaurant 龍笙棧       Dim Sum Restaurant
# 3                                   360 Restaurant                 Wine Bar
# 4                          Swatow Restaurant 汕頭小食家       Chinese Restaurant
# 5                   Goldstone Noodle Restaurant 金石             Noodle House
# 6                            Victoria's Restaurant               Restaurant
# 8                         New Sky Restaurant 小沙田食家       Chinese Restaurant
# 9                   The Hot House Restaurant & Bar      American Restaurant
# 10                    Aroma Fine Indian Restaurant        Indian Restaurant
# 11                          Azure Restaurant & Bar               Restaurant
# 12  Sassafraz | Cafe | Restaurant | Private Events              Event Space
# 13             Richtree Natural Market Restaurants               Restaurant
# 14                         Victor Restaurant & Bar                      Bar
# 16                  Insomnia Restaurant and Lounge               Restaurant
# 17         Tasty's Caribbean Restaurant & Catering     Caribbean Restaurant
# 19                 Bright Pearl Seafood Restaurant       Chinese Restaurant
# 20                         The Lakeview Restaurant                    Diner
# 21                   Hong Shing Chinese Restaurant       Chinese Restaurant
# 24                        Ka Chi Korean Restaurant        Korean Restaurant
# 25               Kensington Cornerstone Restaurant           Breakfast Spot
# 26                               Tundra Restaurant               Restaurant
# 27                     Woodlot Restaurant & Bakery  New American Restaurant
# 28                               Studio Restaurant           Breakfast Spot
# 29               El Rancho Restaurant & Night Club                Nightclub
#
#                      address        lat        lng postalCode state
# 0        110 Chestnut Street  43.654884 -79.385931    M5G 1R3    ON
# 1                181 Bay St.  43.647232 -79.377591    M5J 2T3    ON
# 2           323 Spadina Ave.  43.654318 -79.398650    M5T 2E9    ON
# 3             301 Front St W  43.642537 -79.387042    M5V 2T6    ON
# 4           309 Spadina Ave.  43.653866 -79.398334    M5T 2E6    ON
# 5            266 Spadina Ave  43.652278 -79.398039    M5T 2E4    ON
# 6        37 King Street East  43.649298 -79.376431    M5C 1E9    ON
# 8           353 Spadina Ave.  43.655337 -79.398897    M5T 2G3    ON
# 9               35 Church St  43.648683 -79.373741    M5E 1T3    ON
# 10            287 King St. W  43.646463 -79.389644    M5V 1J5    ON
# 11             225 Frnt St W  43.644749 -79.385113    M5V 2X3    ON
# 12     100 Cumberland Street  43.670342 -79.391041    M5R 1A6    ON
# 13             14 Queen St W  43.652614 -79.380231    M5H 3X4    ON
# 14          30 Mercer Street  43.645634 -79.391125    M5V 1H3    ON
# 16         563 Bloor St West  43.665180 -79.410966    M5S 1Y6    ON
# 17           405 Spadina Ave  43.656794 -79.399251    M5T 2G6    ON
# 19    346-348 Spadina Avenue  43.654219 -79.399125    M5T 2G2    ON
# 20         1132 Dundas St. W  43.649435 -79.420390    M6J 1X2    ON
# 21           195 Dundas St W  43.654925 -79.387089    M5G 1C7    ON
# 24           8 St Andrew St.  43.654307 -79.399277    M5T 1K6    ON
# 25        2A Kensington Ave.  43.652803 -79.399958    M5T 2J7    ON
# 26  145 Richmond Street West  43.650010 -79.385608    M5H 2L2    ON
# 27       293 Palmerston Ave.  43.655765 -79.409929    M6J 2J3    ON
# 28            389 Church St.  43.661500 -79.379319        M5B    ON
# 29           430 College St.  43.656673 -79.407101    M5T 1T3    ON

# %% [markdown]
# ## **Search for Cafeteria**

# %%
# search for Cafeteria
search_query = 'Cafeteria'
radius = 10000

# Define the corresponding URL
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(ClIENT_ID, ClIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=4FQQJE2LMGVLERRRE2BOFR1LQQR5ZEHFLTD1WRAFKOFT4TI0&client_secret=RCSNR5TH31NQRG2QYCHK101HRMTUZHBB2TSJ1CJU5UOGRXRQ&ll=43.653963,-79.387207&v=20180604&query=Cafeteria&radius=10000&limit=30'

# %%
# Send the GET Request and examine the results
cresults = requests.get(url).json()
#cresults

# %%
# assign relevant part of JSON to venues
venues = cresults['response']['venues']

# tranform venues into a dataframe
Cafeteria_dataframe = json_normalize(venues)
Cafeteria_dataframe.head()
# Out:
#                                           categories  hasPerk  \
# 0  [{'name': 'Fast Food Restaurant', 'primary': T...    False
# 1  [{'name': 'Asian Restaurant', 'primary': True,...    False
# 2  [{'name': 'Mexican Restaurant', 'primary': Tru...    False
# 3  [{'name': 'College Cafeteria', 'primary': True...    False
# 4  [{'name': 'Cafeteria', 'primary': True, 'icon'...    False
#
#                          id                           location.address  \
# 0  4f9165bde4b04fef0087e4e2  The Hospital for Sick Children (SickKids)
# 1  528e99a211d262edc3708a6f                            388 Spadina Ave
# 2  56b2c90a498e9f0e73d6bed6                             974 College St
# 3  4ec2b68a8231a83de8c45191                             100 McCaul St.
# 4  53bd6dfe498e6c1d3bc9333e                                        NaN
#
#   location.cc location.city location.country location.crossStreet  \
# 0          CA       Toronto           Canada                  NaN
# 1          CA       Toronto           Canada         at Nassau St
# 2          CA       Toronto           Canada                  NaN
# 3          CA       Toronto           Canada         Second Floor
# 4          CA       Toronto           Canada                  NaN
#
#    location.distance                          location.formattedAddress  \
# 0                372  [The Hospital for Sick Children (SickKids), To...
# 1                977  [388 Spadina Ave (at Nassau St), Toronto ON M5...
# 2               3260       [974 College St, Toronto ON M6H 1A5, Canada]
# 3                389  [100 McCaul St. (Second Floor), Toronto ON, Ca...
# 4                260                               [Toronto ON, Canada]
#
#                              location.labeledLatLngs  location.lat  \
# 0  [{'label': 'display', 'lng': -79.3860632405679...     43.657209
# 1  [{'label': 'display', 'lng': -79.3991632002347...     43.655454
# 2  [{'label': 'display', 'lng': -79.4276775859151...     43.653419
# 3  [{'label': 'display', 'lng': -79.3917616904054...     43.652780
# 4  [{'label': 'display', 'lng': -79.389443, 'lat'...     43.655657
#
#    location.lng location.postalCode location.state  \
# 0    -79.386063                 NaN             ON
# 1    -79.399163             M5T 2G5             ON
# 2    -79.427678             M6H 1A5             ON
# 3    -79.391762                 NaN             ON
# 4    -79.389443                 NaN             ON
#
#                             name    referralId
# 0                      Cafeteria  v-1550348401
# 1              Stay Cafeteria 慢走  v-1550348401
# 2                      Cafeteria  v-1550348401
# 3                 OCAD Cafeteria  v-1550348401
# 4  Industrial Alliance Cafeteria  v-1550348401

# %% [markdown]
# ## **Clean Cafeteria Dataframe**

# %%
# keep only columns that include venue name, and anything that is associated with location
Cafeteria_clean_columns = ['name', 'categories'] + [col for col in Cafeteria_dataframe.columns if col.startswith('location.')]+ ['id']
clean_Cafeteria_dataframe = Cafeteria_dataframe.loc[:,Cafeteria_clean_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list4 = row['categories']
    except:
        categories_list4 = row['venue.categories']
        
    if len(categories_list4) == 0:
        return None
    else:
        return categories_list4[0]['name']

# filter the category for each row
clean_Cafeteria_dataframe['categories'] = clean_Cafeteria_dataframe.apply(get_category_type, axis=1)

# clean column names by keeping only last term
clean_Cafeteria_dataframe.columns = [column.split('.')[-1] for column in clean_Cafeteria_dataframe.columns]

clean_Cafeteria_dataframe.head()
# Out:
#                             name            categories  \
# 0                      Cafeteria  Fast Food Restaurant
# 1              Stay Cafeteria 慢走      Asian Restaurant
# 2                      Cafeteria    Mexican Restaurant
# 3                 OCAD Cafeteria     College Cafeteria
# 4  Industrial Alliance Cafeteria             Cafeteria
#
#                                      address  cc     city country  \
# 0  The Hospital for Sick Children (SickKids)  CA  Toronto  Canada
# 1                            388 Spadina Ave  CA  Toronto  Canada
# 2                             974 College St  CA  Toronto  Canada
# 3                             100 McCaul St.  CA  Toronto  Canada
# 4                                        NaN  CA  Toronto  Canada
#
#     crossStreet  distance                                   formattedAddress  \
# 0           NaN       372  [The Hospital for Sick Children (SickKids), To...
# 1  at Nassau St       977  [388 Spadina Ave (at Nassau St), Toronto ON M5...
# 2           NaN      3260       [974 College St, Toronto ON M6H 1A5, Canada]
# 3  Second Floor       389  [100 McCaul St. (Second Floor), Toronto ON, Ca...
# 4           NaN       260                               [Toronto ON, Canada]
#
#                                       labeledLatLngs        lat        lng  \
# 0  [{'label': 'display', 'lng': -79.3860632405679...  43.657209 -79.386063
# 1  [{'label': 'display', 'lng': -79.3991632002347...  43.655454 -79.399163
# 2  [{'label': 'display', 'lng': -79.4276775859151...  43.653419 -79.427678
# 3  [{'label': 'display', 'lng': -79.3917616904054...  43.652780 -79.391762
# 4  [{'label': 'display', 'lng': -79.389443, 'lat'...  43.655657 -79.389443
#
#   postalCode state                        id
# 0        NaN    ON  4f9165bde4b04fef0087e4e2
# 1    M5T 2G5    ON  528e99a211d262edc3708a6f
# 2    M6H 1A5    ON  56b2c90a498e9f0e73d6bed6
# 3        NaN    ON  4ec2b68a8231a83de8c45191
# 4        NaN    ON  53bd6dfe498e6c1d3bc9333e

# %%
# delete unnecessary columns
clean_Cafeteria_dataframe2= clean_Cafeteria_dataframe.drop(['cc', 'city', 'country', 'crossStreet', 'distance', 'formattedAddress',\
                                        'labeledLatLngs', 'id'], axis=1)
clean_Cafeteria_dataframe2
# Out:
#                                      name            categories  \
# 0                               Cafeteria  Fast Food Restaurant
# 1                       Stay Cafeteria 慢走      Asian Restaurant
# 2                               Cafeteria    Mexican Restaurant
# 3                          OCAD Cafeteria     College Cafeteria
# 4           Industrial Alliance Cafeteria             Cafeteria
# 5                         Dears Cafeteria          Dessert Shop
# 6                         Sears Cafeteria            Food Court
# 7                 Chestnut Tree Cafeteria             Cafeteria
# 8               Macdonald Block Cafeteria             Cafeteria
# 9           De La Salle College Cafeteria     College Cafeteria
# 10                      Med Sci Cafeteria     College Cafeteria
# 11                  Ryerson Hub Cafeteria     College Cafeteria
# 12                     SickKids Cafeteria            Food Court
# 13                      Robarts Cafeteria     College Cafeteria
# 14                       Rogers Cafeteria            Food Court
# 15                          OMP Cafeteria             Cafeteria
# 16                      Choices Cafeteria            Food Court
# 17    Cafeteria, Lawrence Park Collegiate           Event Space
# 18                             Marketeria            Restaurant
# 19    Cafeteria, Lawrence Park Collegiate           High School
# 20                       Kasala Cafeteria    African Restaurant
# 21                               One Hour    Chinese Restaurant
# 22               Estonian House Cafeteria                  Café
# 23                                The Hub     College Cafeteria
# 24                           CC Cafeteria     College Cafeteria
# 25     Lawrence Park Collegiate Cafeteria           High School
# 26                      Glendon Cafeteria     College Cafeteria
# 27                          Innis College        Student Center
# 28                             Radio Cafe            Food Court
# 29  6th Floor Cafeteria 12 Concorde Place                  Café
#
#                                       address        lat        lng  \
# 0   The Hospital for Sick Children (SickKids)  43.657209 -79.386063
# 1                             388 Spadina Ave  43.655454 -79.399163
# 2                              974 College St  43.653419 -79.427678
# 3                              100 McCaul St.  43.652780 -79.391762
# 4                                         NaN  43.655657 -79.389443
# 5                                         NaN  43.654179 -79.392555
# 6                                       Yonge  43.656038 -79.380672
# 7                          89 Chestnut Street  43.648231 -79.384045
# 8                                         NaN  43.663212 -79.388062
# 9                          131 Farnham Avenue  43.683003 -79.397815
# 10                                        NaN  43.660260 -79.392977
# 11                           350 Victoria St.  43.658475 -79.377653
# 12                      555 University Avenue  43.657584 -79.375652
# 13                         130 St. George St.  43.664864 -79.399766
# 14                                        NaN  43.669904 -79.379748
# 15                           1 Mount Pleasant  43.669801 -79.379790
# 16                         200 Bloor Street E  43.671411 -79.381849
# 17                                        NaN  43.723286 -79.412222
# 18                                30 Bond St.  43.653585 -79.378843
# 19                                        NaN  43.721732 -79.409600
# 20                                      Bloor  43.660759 -79.424018
# 21                           435 Spadina Ave.  43.657399 -79.399649
# 22                       958 Broadview avenue  43.681763 -79.358246
# 23                           350 Victoria St.  43.658585 -79.380622
# 24                             951 Carlaw Ave  43.684631 -79.348862
# 25                                        NaN  43.722757 -79.413734
# 26                           2275 Bayview Ave  43.727383 -79.378080
# 27                               2 Sussex Ave  43.665556 -79.399298
# 28                          333 Bloor st east  43.671696 -79.380617
# 29                          12 Concorde Place  43.721861 -79.329339
#
#    postalCode state
# 0         NaN    ON
# 1     M5T 2G5    ON
# 2     M6H 1A5    ON
# 3         NaN    ON
# 4         NaN    ON
# 5         NaN   NaN
# 6         NaN    ON
# 7         NaN    ON
# 8         NaN   NaN
# 9     M4V 1H7    ON
# 10        NaN    ON
# 11        NaN    ON
# 12        NaN    ON
# 13        NaN    ON
# 14        NaN    ON
# 15        NaN    ON
# 16        NaN    ON
# 17        NaN   NaN
# 18    M5B 1W8    ON
# 19        NaN   NaN
# 20        NaN   NaN
# 21    M5T 2T6    ON
# 22        NaN    ON
# 23    M5B 2K3    ON
# 24        NaN    ON
# 25        NaN    ON
# 26        NaN    ON
# 27    M5S 1J5    ON
# 28        NaN    ON
# 29    m3c 3k7    ON

# %%
# delete rows with none values
df_Cafeteria = clean_Cafeteria_dataframe2.dropna(axis=0, how='any', thresh=None, subset=None, inplace=False)
df_Cafeteria
# Out:
#                                      name          categories  \
# 1                       Stay Cafeteria 慢走    Asian Restaurant
# 2                               Cafeteria  Mexican Restaurant
# 9           De La Salle College Cafeteria   College Cafeteria
# 18                             Marketeria          Restaurant
# 21                               One Hour  Chinese Restaurant
# 23                                The Hub   College Cafeteria
# 27                          Innis College      Student Center
# 29  6th Floor Cafeteria 12 Concorde Place                Café
#
#                address        lat        lng postalCode state
# 1      388 Spadina Ave  43.655454 -79.399163    M5T 2G5    ON
# 2       974 College St  43.653419 -79.427678    M6H 1A5    ON
# 9   131 Farnham Avenue  43.683003 -79.397815    M4V 1H7    ON
# 18         30 Bond St.  43.653585 -79.378843    M5B 1W8    ON
# 21    435 Spadina Ave.  43.657399 -79.399649    M5T 2T6    ON
# 23    350 Victoria St.  43.658585 -79.380622    M5B 2K3    ON
# 27        2 Sussex Ave  43.665556 -79.399298    M5S 1J5    ON
# 29   12 Concorde Place  43.721861 -79.329339    m3c 3k7    ON

# %% [markdown]
# ## **Search for Shopping Stores**

# %%
# search for Shopping
search_query = 'Shopping'
radius = 1000

# Define the corresponding URL
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(ClIENT_ID, ClIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=4FQQJE2LMGVLERRRE2BOFR1LQQR5ZEHFLTD1WRAFKOFT4TI0&client_secret=RCSNR5TH31NQRG2QYCHK101HRMTUZHBB2TSJ1CJU5UOGRXRQ&ll=43.653963,-79.387207&v=20180604&query=Shopping&radius=1000&limit=30'

# %%
# Send the GET Request and examine the results
sresults = requests.get(url).json()
#sresults

# %%
# assign relevant part of JSON to venues
venues = sresults['response']['venues']

# tranform venues into a dataframe
Shopping_dataframe = json_normalize(venues)
Shopping_dataframe.head()
# Out:
#                                           categories  hasPerk  \
# 0  [{'name': 'Shopping Mall', 'primary': True, 'i...    False
# 1  [{'name': 'Shopping Mall', 'primary': True, 'i...    False
# 2  [{'name': 'Shopping Mall', 'primary': True, 'i...    False
# 3  [{'name': 'Department Store', 'primary': True,...    False
# 4  [{'name': 'Office', 'primary': True, 'icon': {...    False
#
#                          id    location.address location.cc location.city  \
# 0  4ad4c062f964a520fcf720e3     280 Spadina Ave          CA       Toronto
# 1  4ad77a12f964a520260b21e3        220 Yonge St          CA       Toronto
# 2  4b9e86dff964a520e6eb36e3  66 Wellington St W          CA       Toronto
# 3  5840cafe06f1a34af80cc609    176 Yonge Street          CA       Toronto
# 4  4b83d653f964a520d91231e3   461 King St. West          CA       Toronto
#
#   location.country location.crossStreet  location.distance  \
# 0           Canada       at Dundas St W                897
# 1           Canada  btwn Queen & Dundas                529
# 2           Canada    btw York & Bay St                908
# 3           Canada    Queen Street West                688
# 4           Canada                  NaN                974
#
#                            location.formattedAddress  \
# 0  [280 Spadina Ave (at Dundas St W), Toronto ON ...
# 1  [220 Yonge St (btwn Queen & Dundas), Toronto O...
# 2  [66 Wellington St W (btw York & Bay St), Toron...
# 3  [176 Yonge Street (Queen Street West), Toronto...
# 4    [461 King St. West, Toronto ON M5V 1K4, Canada]
#
#                              location.labeledLatLngs  location.lat  \
# 0  [{'label': 'display', 'lng': -79.3982223289847...     43.652774
# 1                                                NaN     43.654148
# 2  [{'label': 'display', 'lng': -79.3809318535714...     43.647184
# 3  [{'label': 'display', 'lng': -79.379192, 'lat'...     43.651810
# 4  [{'label': 'display', 'lng': -79.3960059245408...     43.647958
#
#    location.lng          location.neighborhood location.postalCode  \
# 0    -79.398222                            NaN             M5T 3A5
# 1    -79.380639  Downtown Toronto, Toronto, ON             M5B 2H1
# 2    -79.380932                            NaN             M5K 1A1
# 3    -79.379192                            NaN             M5C 2L7
# 4    -79.396006                            NaN             M5V 1K4
#
#   location.state                                        name    referralId
# 0             ON                Dragon City Shopping Mall 龍城  v-1550348460
# 1             ON                     CF Toronto Eaton Centre  v-1550348460
# 2             ON                TD Centre Shopping Concourse  v-1550348460
# 3             ON  Saks Fifth Avenue Club - Personal Shopping  v-1550348460
# 4             ON             Yellow Pages - RedFlagDeals.com  v-1550348460

# %% [markdown]
# ## **Clean Shopping Dataframe**

# %%
# keep only columns that include venue name, and anything that is associated with location
Shopping_clean_columns = ['name', 'categories'] + [col for col in Shopping_dataframe.columns if col.startswith('location.')]+ ['id']
clean_Shopping_dataframe = Shopping_dataframe.loc[:,Shopping_clean_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list5 = row['categories']
    except:
        categories_list5 = row['venue.categories']
        
    if len(categories_list5) == 0:
        return None
    else:
        return categories_list5[0]['name']

# filter the category for each row
clean_Shopping_dataframe['categories'] = clean_Shopping_dataframe.apply(get_category_type, axis=1)

# clean column names by keeping only last term
clean_Shopping_dataframe.columns = [column.split('.')[-1] for column in clean_Shopping_dataframe.columns]

clean_Shopping_dataframe.head()
# Out:
#                                          name        categories  \
# 0                Dragon City Shopping Mall 龍城     Shopping Mall
# 1                     CF Toronto Eaton Centre     Shopping Mall
# 2                TD Centre Shopping Concourse     Shopping Mall
# 3  Saks Fifth Avenue Club - Personal Shopping  Department Store
# 4             Yellow Pages - RedFlagDeals.com            Office
#
#               address  cc     city country          crossStreet  distance  \
# 0     280 Spadina Ave  CA  Toronto  Canada       at Dundas St W       897
# 1        220 Yonge St  CA  Toronto  Canada  btwn Queen & Dundas       529
# 2  66 Wellington St W  CA  Toronto  Canada    btw York & Bay St       908
# 3    176 Yonge Street  CA  Toronto  Canada    Queen Street West       688
# 4   461 King St. West  CA  Toronto  Canada                  NaN       974
#
#                                     formattedAddress  \
# 0  [280 Spadina Ave (at Dundas St W), Toronto ON ...
# 1  [220 Yonge St (btwn Queen & Dundas), Toronto O...
# 2  [66 Wellington St W (btw York & Bay St), Toron...
# 3  [176 Yonge Street (Queen Street West), Toronto...
# 4    [461 King St. West, Toronto ON M5V 1K4, Canada]
#
#                                       labeledLatLngs        lat        lng  \
# 0  [{'label': 'display', 'lng': -79.3982223289847...  43.652774 -79.398222
# 1                                                NaN  43.654148 -79.380639
# 2  [{'label': 'display', 'lng': -79.3809318535714...  43.647184 -79.380932
# 3  [{'label': 'display', 'lng': -79.379192, 'lat'...  43.651810 -79.379192
# 4  [{'label': 'display', 'lng': -79.3960059245408...  43.647958 -79.396006
#
#                     neighborhood postalCode state                        id
# 0                            NaN    M5T 3A5    ON  4ad4c062f964a520fcf720e3
# 1  Downtown Toronto, Toronto, ON    M5B 2H1    ON  4ad77a12f964a520260b21e3
# 2                            NaN    M5K 1A1    ON  4b9e86dff964a520e6eb36e3
# 3                            NaN    M5C 2L7    ON  5840cafe06f1a34af80cc609
# 4                            NaN    M5V 1K4    ON  4b83d653f964a520d91231e3

# %%
# delete unnecessary columns
clean_Shopping_dataframe2= clean_Shopping_dataframe.drop(['cc', 'city', 'country', 'crossStreet', 'distance', 'formattedAddress',\
                                        'labeledLatLngs', 'neighborhood', 'id'], axis=1)
clean_Shopping_dataframe2
# Out:
#                                          name        categories  \
# 0                Dragon City Shopping Mall 龍城     Shopping Mall
# 1                     CF Toronto Eaton Centre     Shopping Mall
# 2                TD Centre Shopping Concourse     Shopping Mall
# 3  Saks Fifth Avenue Club - Personal Shopping  Department Store
# 4             Yellow Pages - RedFlagDeals.com            Office
#
#               address        lat        lng postalCode state
# 0     280 Spadina Ave  43.652774 -79.398222    M5T 3A5    ON
# 1        220 Yonge St  43.654148 -79.380639    M5B 2H1    ON
# 2  66 Wellington St W  43.647184 -79.380932    M5K 1A1    ON
# 3    176 Yonge Street  43.651810 -79.379192    M5C 2L7    ON
# 4   461 King St. West  43.647958 -79.396006    M5V 1K4    ON

# %%
# delete rows which its category is not Shopping Mall
df_Shopping = clean_Shopping_dataframe2[clean_Shopping_dataframe2.categories == 'Shopping Mall']
df_Shopping
# Out:
#                            name     categories             address        lat  \
# 0  Dragon City Shopping Mall 龍城  Shopping Mall     280 Spadina Ave  43.652774
# 1       CF Toronto Eaton Centre  Shopping Mall        220 Yonge St  43.654148
# 2  TD Centre Shopping Concourse  Shopping Mall  66 Wellington St W  43.647184
#
#          lng postalCode state
# 0 -79.398222    M5T 3A5    ON
# 1 -79.380639    M5B 2H1    ON
# 2 -79.380932    M5K 1A1    ON

# %% [markdown]
# ## **Generate map to visualize hotels, shopping stores and Cafeteria and how they cluster together**

# %%
# create dataframe of hotels, shopping stores and Cafeteria
hotel_neighbourhood_df = pd.concat([df_hotel, df_Cafeteria, df_Shopping], ignore_index=True)
hotel_neighbourhood_df
# Out:
#                                      name          categories  \
# 0           Sheraton Centre Toronto Hotel               Hotel
# 1                          Grand Ballroom         Event Space
# 2                       Stay Cafeteria 慢走    Asian Restaurant
# 3                               Cafeteria  Mexican Restaurant
# 4           De La Salle College Cafeteria   College Cafeteria
# 5                              Marketeria          Restaurant
# 6                                One Hour  Chinese Restaurant
# 7                                 The Hub   College Cafeteria
# 8                           Innis College      Student Center
# 9   6th Floor Cafeteria 12 Concorde Place                Café
# 10           Dragon City Shopping Mall 龍城       Shopping Mall
# 11                CF Toronto Eaton Centre       Shopping Mall
# 12           TD Centre Shopping Concourse       Shopping Mall
#
#                   address        lat        lng postalCode state
# 0   123 Queen Street West  43.651052 -79.384026    M5H 2M9    ON
# 1         123 Queen St. W  43.651217 -79.383771    M5H 2M9    ON
# 2         388 Spadina Ave  43.655454 -79.399163    M5T 2G5    ON
# 3          974 College St  43.653419 -79.427678    M6H 1A5    ON
# 4      131 Farnham Avenue  43.683003 -79.397815    M4V 1H7    ON
# 5             30 Bond St.  43.653585 -79.378843    M5B 1W8    ON
# 6        435 Spadina Ave.  43.657399 -79.399649    M5T 2T6    ON
# 7        350 Victoria St.  43.658585 -79.380622    M5B 2K3    ON
# 8            2 Sussex Ave  43.665556 -79.399298    M5S 1J5    ON
# 9       12 Concorde Place  43.721861 -79.329339    m3c 3k7    ON
# 10        280 Spadina Ave  43.652774 -79.398222    M5T 3A5    ON
# 11           220 Yonge St  43.654148 -79.380639    M5B 2H1    ON
# 12     66 Wellington St W  43.647184 -79.380932    M5K 1A1    ON

# %%
# Generate map to visualize hotel neighbourhood including shopping stores and Cafeteria 
hotel_map = folium.Map(location=[latitude, longitude], zoom_start=14)

for lat, lng, name, categories, address in zip(hotel_neighbourhood_df['lat'], hotel_neighbourhood_df['lng'], 
                                           hotel_neighbourhood_df['name'], hotel_neighbourhood_df['categories'],\
                                               hotel_neighbourhood_df['address']):
    label = '{}, {}'.format(name, address)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='blue',
        fill_opacity=0.7,
        parse_html=False).add_to(hotel_map)  
    
hotel_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## **Generate map to visualize Park, Restaurant and Cafeteria and how they cluster together**

# %%
# create dataframe of Park, Restaurant and Cafeteria
park_neighbourhood_df = pd.concat([df_park, df_Restaurant, df_Cafeteria,], ignore_index=True)
park_neighbourhood_df
# Out:
#                                               name               categories  \
# 0                                     Queen's Park                     Park
# 1                           Trinity Bellwoods Park                     Park
# 2                             Bellevue Square Park                     Park
# 3                              Riverdale Park West                     Park
# 4                              Riverdale Park East                     Park
# 5                                Barbara Hall Park                     Park
# 6                                        High Park                     Park
# 7                               Canoe Landing Park                     Park
# 8                       Sir Winston Churchill Park                     Park
# 9                                  Coronation Park                     Park
# 10                 Hemispheres Restaurant & Bistro      American Restaurant
# 11                               Marché Restaurant               Restaurant
# 12                          Rol San Restaurant 龍笙棧       Dim Sum Restaurant
# 13                                  360 Restaurant                 Wine Bar
# 14                         Swatow Restaurant 汕頭小食家       Chinese Restaurant
# 15                  Goldstone Noodle Restaurant 金石             Noodle House
# 16                           Victoria's Restaurant               Restaurant
# 17                        New Sky Restaurant 小沙田食家       Chinese Restaurant
# 18                  The Hot House Restaurant & Bar      American Restaurant
# 19                    Aroma Fine Indian Restaurant        Indian Restaurant
# 20                          Azure Restaurant & Bar               Restaurant
# 21  Sassafraz | Cafe | Restaurant | Private Events              Event Space
# 22             Richtree Natural Market Restaurants               Restaurant
# 23                         Victor Restaurant & Bar                      Bar
# 24                  Insomnia Restaurant and Lounge               Restaurant
# 25         Tasty's Caribbean Restaurant & Catering     Caribbean Restaurant
# 26                 Bright Pearl Seafood Restaurant       Chinese Restaurant
# 27                         The Lakeview Restaurant                    Diner
# 28                   Hong Shing Chinese Restaurant       Chinese Restaurant
# 29                        Ka Chi Korean Restaurant        Korean Restaurant
# 30               Kensington Cornerstone Restaurant           Breakfast Spot
# 31                               Tundra Restaurant               Restaurant
# 32                     Woodlot Restaurant & Bakery  New American Restaurant
# 33                               Studio Restaurant           Breakfast Spot
# 34               El Rancho Restaurant & Night Club                Nightclub
# 35                               Stay Cafeteria 慢走         Asian Restaurant
# 36                                       Cafeteria       Mexican Restaurant
# 37                   De La Salle College Cafeteria        College Cafeteria
# 38                                      Marketeria               Restaurant
# 39                                        One Hour       Chinese Restaurant
# 40                                         The Hub        College Cafeteria
# 41                                   Innis College           Student Center
# 42           6th Floor Cafeteria 12 Concorde Place                     Café
#
#                          address        lat        lng postalCode state
# 0                University Ave.  43.663946 -79.392180    M5R 2E8    ON
# 1             1053 Dundas St. W.  43.647072 -79.413756    M5H 2N2    ON
# 2   btwn Bellevue & Augusta Ave.  43.653610 -79.402199    M5T 2N4    ON
# 3                500 Gerrard St.  43.666048 -79.360941    M5A 2H3    ON
# 4              550 Broadview Ave  43.669951 -79.355493    M4K 2P1    ON
# 5                  519 Church St  43.666879 -79.381068    M4Y 2K9    ON
# 6               1873 Bloor St. W  43.646479 -79.463425    M6R 2Z3    ON
# 7              50 Fort York Blvd  43.638762 -79.397067    M5V 3Z1    ON
# 8             301 St Clair Ave W  43.683732 -79.409881    M4V 1S4    ON
# 9         711 Lake Shore Blvd. W  43.634553 -79.405403    M5V 3T7    ON
# 10           110 Chestnut Street  43.654884 -79.385931    M5G 1R3    ON
# 11                   181 Bay St.  43.647232 -79.377591    M5J 2T3    ON
# 12              323 Spadina Ave.  43.654318 -79.398650    M5T 2E9    ON
# 13                301 Front St W  43.642537 -79.387042    M5V 2T6    ON
# 14              309 Spadina Ave.  43.653866 -79.398334    M5T 2E6    ON
# 15               266 Spadina Ave  43.652278 -79.398039    M5T 2E4    ON
# 16           37 King Street East  43.649298 -79.376431    M5C 1E9    ON
# 17              353 Spadina Ave.  43.655337 -79.398897    M5T 2G3    ON
# 18                  35 Church St  43.648683 -79.373741    M5E 1T3    ON
# 19                287 King St. W  43.646463 -79.389644    M5V 1J5    ON
# 20                 225 Frnt St W  43.644749 -79.385113    M5V 2X3    ON
# 21         100 Cumberland Street  43.670342 -79.391041    M5R 1A6    ON
# 22                 14 Queen St W  43.652614 -79.380231    M5H 3X4    ON
# 23              30 Mercer Street  43.645634 -79.391125    M5V 1H3    ON
# 24             563 Bloor St West  43.665180 -79.410966    M5S 1Y6    ON
# 25               405 Spadina Ave  43.656794 -79.399251    M5T 2G6    ON
# 26        346-348 Spadina Avenue  43.654219 -79.399125    M5T 2G2    ON
# 27             1132 Dundas St. W  43.649435 -79.420390    M6J 1X2    ON
# 28               195 Dundas St W  43.654925 -79.387089    M5G 1C7    ON
# 29               8 St Andrew St.  43.654307 -79.399277    M5T 1K6    ON
# 30            2A Kensington Ave.  43.652803 -79.399958    M5T 2J7    ON
# 31      145 Richmond Street West  43.650010 -79.385608    M5H 2L2    ON
# 32           293 Palmerston Ave.  43.655765 -79.409929    M6J 2J3    ON
# 33                389 Church St.  43.661500 -79.379319        M5B    ON
# 34               430 College St.  43.656673 -79.407101    M5T 1T3    ON
# 35               388 Spadina Ave  43.655454 -79.399163    M5T 2G5    ON
# 36                974 College St  43.653419 -79.427678    M6H 1A5    ON
# 37            131 Farnham Avenue  43.683003 -79.397815    M4V 1H7    ON
# 38                   30 Bond St.  43.653585 -79.378843    M5B 1W8    ON
# 39              435 Spadina Ave.  43.657399 -79.399649    M5T 2T6    ON
# 40              350 Victoria St.  43.658585 -79.380622    M5B 2K3    ON
# 41                  2 Sussex Ave  43.665556 -79.399298    M5S 1J5    ON
# 42             12 Concorde Place  43.721861 -79.329339    m3c 3k7    ON

# %%
# Generate map to visualize park neighbourhood including Restaurant and Cafeteria 
park_map = folium.Map(location=[latitude, longitude], zoom_start=14)

for lat, lng, name, categories, address in zip(park_neighbourhood_df['lat'], park_neighbourhood_df['lng'], 
                                           park_neighbourhood_df['name'], park_neighbourhood_df['categories'],\
                                               park_neighbourhood_df['address']):
    label = '{}, {}'.format(name, address)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='blue',
        fill_opacity=0.7,
        parse_html=False).add_to(park_map)  
    
park_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Notebook on Watson
# https://dataplatform.cloud.ibm.com/analytics/notebooks/v2/a01c79f1-c037-4715-8cc2-0beae6740106/view?access_token=737adbc5296a0fdd4843903f12b0cc22287b3dd3f5b37b1204c4801034294d81

# %% [markdown]
# ### **Note: I share the above link with you to see maps**
